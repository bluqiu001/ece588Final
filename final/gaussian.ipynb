# %%
import imageio
from matplotlib import pyplot as plt
import numpy as np
from scipy import signal
from PIL import Image
from scipy import ndimage

# %%
def get_image(i):
    im = imageio.imread('test_images2/generated_images/' + str(i) + '.png')
    box_blur = (1/9.0) * np.array([[1,1,1],[1,1,1],[1,1,1]])
    new_im = np.zeros((256, 256, 4))
    for i in range (4):
        out = ndimage.gaussian_filter(im[:,:,i], sigma=1)
        new_im[:,:,i] = np.round(out).astype(np.uint8)

    new_im = new_im.astype(np.uint8)

    return new_im

# %%
im = imageio.imread('test_images2/generated_images/' + str(6743) + '.png')
# Out:
# /var/folders/s0/mc6fh4zj1tbf17y2y7tyhf800000gn/T/ipykernel_7809/1501481997.py:1: DeprecationWarning: Starting with ImageIO v3 the behavior of this function will switch to that of iio.v3.imread. To keep the current behavior (and make this warning disappear) use `import imageio.v2 as imageio` or call `imageio.v2.imread` directly.
#   im = imageio.imread('test_images2/generated_images/' + str(6743) + '.png')

# %%
from matplotlib import pyplot as plt
plt.imshow(im)
plt.show()

# %%
new_im = get_image(6743)
# Out:
# /var/folders/s0/mc6fh4zj1tbf17y2y7tyhf800000gn/T/ipykernel_7809/4124390872.py:2: DeprecationWarning: Starting with ImageIO v3 the behavior of this function will switch to that of iio.v3.imread. To keep the current behavior (and make this warning disappear) use `import imageio.v2 as imageio` or call `imageio.v2.imread` directly.
#   im = imageio.imread('test_images2/generated_images/' + str(i) + '.png')

# %%
from matplotlib import pyplot as plt
plt.imshow(new_im)
plt.show()

# %%
for i in range (1, 7039):
    new_im = get_image(i)
    im = Image.fromarray(new_im)
    im.save("gaussian/images/" + str(i) + ".png")
# Out:
# /var/folders/s0/mc6fh4zj1tbf17y2y7tyhf800000gn/T/ipykernel_7809/4124390872.py:2: DeprecationWarning: Starting with ImageIO v3 the behavior of this function will switch to that of iio.v3.imread. To keep the current behavior (and make this warning disappear) use `import imageio.v2 as imageio` or call `imageio.v2.imread` directly.
#   im = imageio.imread('test_images2/generated_images/' + str(i) + '.png')

# %%
import tensorflow as tf

# %%
new_model = tf.keras.models.load_model('classification_model.h5')
# Out:
# 2022-12-08 16:05:07.128264: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:305] Could not identify NUMA node of platform GPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# 2022-12-08 16:05:07.128603: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:271] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 0 MB memory) -> physical PluggableDevice (device: 0, name: METAL, pci bus id: <undefined>)
# Metal device set to: Apple M1 Max
#
# systemMemory: 32.00 GB
# maxCacheSize: 10.67 GB

# %%
def get_predictions(file_path, model):
    img_array = tf.keras.utils.image_dataset_from_directory(
                file_path)
    predictions = model.predict(img_array)
    predicted_labels = []
    for prediction in predictions:
        predicted_labels.append(np.argmax(prediction))
    return predicted_labels

# %%
local_means = get_predictions("gaussian", new_model)
# Out:
# Found 7038 files belonging to 1 classes.
# 2022-12-08 16:05:07.972151: W tensorflow/core/platform/profile_utils/cpu_utils.cc:128] Failed to get CPU frequency: 0 Hz
# 2022-12-08 16:05:07.972611: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:112] Plugin optimizer for device_type GPU is enabled.

# %%
local_means.count(0) / (len(local_means))
# Out:
# 0.8123046319977266
